# %%
import pandas as pd
df = pd.read_parquet("/mnt/hdfs/hongli/projects/verl_demo/data/polaris-data-53K.parquet")
import transformers
tokenizer = transformers.AutoTokenizer.from_pretrained("/mnt/hdfs/hongli/model/Qwen3-4B", trust_remote_code=True)

# %%
x  = [tokenizer.apply_chat_template(msg, tokenize=True) for msg in df["prompt"]]

# %%
df["prompt_length"] = [len(i) for i in x]

# %%
df["prompt_length"].max()
# Out:
# 2053
